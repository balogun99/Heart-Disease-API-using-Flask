# %%
import requests

# %%
url = "/predict"

# %%
data = {
    "age": ,
    "sex": ,
    "cp": ,
    "trestbps": ,
    "chol": ,
    "fbs": ,
    "restecg": ,
    "thalach": ,
    "exang": ,
    "oldpeak": ,
    "slope": ,
    "ca": ,
    "thal": 
}

# %%
response = requests.post(url, json=data)
print(response.json)
